# %%
import pandas as pd
df=pd.read_csv("customers.csv")
df
# Out:
#    CustomerID     Name   Age         City
# 0           1    Alice  25.0     New York
# 1           2      Bob  30.0  Los Angeles
# 2           3  Charlie  35.0          NaN
# 3           4    David   NaN      Chicago
# 4           5      Eve  45.0      Houston

# %%
df.set_index('CustomerID',inplace=True)

# %%
df
# Out:
#                Name   Age         City
# CustomerID
# 1             Alice  25.0     New York
# 2               Bob  30.0  Los Angeles
# 3           Charlie  35.0          NaN
# 4             David   NaN      Chicago
# 5               Eve  45.0      Houston

# %%
df.isnull()
# Out:
#              Name    Age   City
# CustomerID
# 1           False  False  False
# 2           False  False  False
# 3           False  False   True
# 4           False   True  False
# 5           False  False  False

# %%
df1=df.fillna({
    'Age':18,
    'City':'UK'})
df1
# Out:
#                Name   Age         City
# CustomerID
# 1             Alice  25.0     New York
# 2               Bob  30.0  Los Angeles
# 3           Charlie  35.0           UK
# 4             David  18.0      Chicago
# 5               Eve  45.0      Houston

# %%
df1=df.fillna(method="ffill")
df1
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_848\1634214753.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1=df.fillna(method="ffill")
#                Name   Age         City
# CustomerID
# 1             Alice  25.0     New York
# 2               Bob  30.0  Los Angeles
# 3           Charlie  35.0  Los Angeles
# 4             David  35.0      Chicago
# 5               Eve  45.0      Houston

# %%
df1=df.ffill()
df1
# Out:
#                Name   Age         City
# CustomerID
# 1             Alice  25.0     New York
# 2               Bob  30.0  Los Angeles
# 3           Charlie  35.0  Los Angeles
# 4             David  35.0      Chicago
# 5               Eve  45.0      Houston

# %%
df1=df.bfill()
df1
# Out:
#                Name   Age         City
# CustomerID
# 1             Alice  25.0     New York
# 2               Bob  30.0  Los Angeles
# 3           Charlie  35.0      Chicago
# 4             David  45.0      Chicago
# 5               Eve  45.0      Houston

# %%
df1=df.dropna(axis=0)
df1
# Out:
#              Name   Age         City
# CustomerID
# 1           Alice  25.0     New York
# 2             Bob  30.0  Los Angeles
# 5             Eve  45.0      Houston

# %%
df1=df.dropna(axis=1)
df1
# Out:
#                Name
# CustomerID
# 1             Alice
# 2               Bob
# 3           Charlie
# 4             David
# 5               Eve

# %%
df1=df.interpolate(method='linear',axis=0,inplace=False)
df1
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_848\3022920658.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df1=df.interpolate(method='linear',axis=0,inplace=False)
#                Name   Age         City
# CustomerID
# 1             Alice  25.0     New York
# 2               Bob  30.0  Los Angeles
# 3           Charlie  35.0          NaN
# 4             David  40.0      Chicago
# 5               Eve  45.0      Houston

# %%
df1=df.interpolate(method="index",axis=0,inplace=False)
df1
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_848\1088112221.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df1=df.interpolate(method="index",axis=0,inplace=False)
#                Name   Age         City
# CustomerID
# 1             Alice  25.0     New York
# 2               Bob  30.0  Los Angeles
# 3           Charlie  35.0          NaN
# 4             David  40.0      Chicago
# 5               Eve  45.0      Houston

# %%
df1=df.interpolate(method='slinear')
df1
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_848\1529492526.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df1=df.interpolate(method='slinear')
#                Name   Age         City
# CustomerID
# 1             Alice  25.0     New York
# 2               Bob  30.0  Los Angeles
# 3           Charlie  35.0          NaN
# 4             David  40.0      Chicago
# 5               Eve  45.0      Houston

# %%
print(df)
print("After dropna function")
df1=df.dropna()
df1
# Out:
#                Name   Age         City
# CustomerID
# 1             Alice  25.0     New York
# 2               Bob  30.0  Los Angeles
# 3           Charlie  35.0          NaN
# 4             David   NaN      Chicago
# 5               Eve  45.0      Houston
# After dropna function
#              Name   Age         City
# CustomerID
# 1           Alice  25.0     New York
# 2             Bob  30.0  Los Angeles
# 5             Eve  45.0      Houston

# %%
df1=df.dropna(thresh=3,axis=0)
df1
# Out:
#              Name   Age         City
# CustomerID
# 1           Alice  25.0     New York
# 2             Bob  30.0  Los Angeles
# 5             Eve  45.0      Houston

# %%
import numpy as np
df1=df.replace(to_replace=np.nan,value=0)
df1
# Out:
#                Name   Age         City
# CustomerID
# 1             Alice  25.0     New York
# 2               Bob  30.0  Los Angeles
# 3           Charlie  35.0            0
# 4             David   0.0      Chicago
# 5               Eve  45.0      Houston

# %%
df1=df.replace({'Age':np.nan},18,regex=True)
df1
# Out:
#                Name   Age         City
# CustomerID
# 1             Alice  25.0     New York
# 2               Bob  30.0  Los Angeles
# 3           Charlie  35.0          NaN
# 4             David  18.0      Chicago
# 5               Eve  45.0      Houston

# %%
print(df["Age"].max())
# Out:
# 45.0

# %%
print(df["Age"].mean())
# Out:
# 33.75

# %%
# %matplotlib inline
(df["Age"]).plot()
# Out:
# <Axes: xlabel='CustomerID'>
